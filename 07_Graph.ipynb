# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamMahajan880/Imapct-Training-DSA-Notes/blob/main/07_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Graph** : -

# %% [markdown]
# --> Graph is a collection of vertices and edges
#
# --> Vertices will be represented by circle, nodes or hole
#
# --> Edges will represent the lines
#
# --> Edges will connect the lines

# %% [markdown]
#  ![1 - Graph.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Degree of a Node**
#
# --> The number of edges connected to each lines

# %% [markdown]
# # **Size of a graph**
#
# --> Size of a graph will represent the total number of graph

# %% [markdown]
# # **Differewnt types of graph**

# %% [markdown]
# a. **Directed graph**:
#
# --> The Directed is indicated between the edges it will be called as Directed graph
#
#
# b. **Un-Directed Graph**:
#
#
# --> If no direction is indicated between the edgesis called as undirected graph

# %% [markdown]
#   ![2 - Directed Grapg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. **Weighted and Un-weighted graph**:
#
# --> If the weighted is specified between the edges then it is called as weighted graph
#
# --> If the weight is not specified between the edges then it called as un-weighted graph.

# %% [markdown]
# ![4 - Wighted & Cyclic Graph.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 3. **Cyclic and Un-Cyclic graph**:
#
# --> If the graph is forming a circle the it is called as cyclic graph.
#
# --> if the graph is not forming a circle then it is called as un-cyclic graph.

# %% [markdown]
# # **Representation of Graphs:**
#
# --> The graphs will be represented in two ways:
#
# 1. Using Multi-dimensional array
#
# 2. Using a list
#
#
# 1. Using Multi-Dimensional Array:
#
# Un-Directed:
#
# -->   A B C D
#     A 0 1 0 1
#     B 1 0 1 0
#     C 0 1 0 1
#     D 1 0 1 0
#
# Directed:
#
# ->  0 A B C D
#
#   0 A 0 1 0 0
#
#   0 B 0 0 1 0
#
#   0 C 0 0 0 1
#
#   0 D 1 0 0 0
#
# Q.
#
#    0 A B C D
#
#    A 0 1 0 0
#
#    B 0 0 1 0
#
#    C 0 0 0 1
#
#    D 1 1 0 0
#
# 2. Using List: Undirected Graph
#
#     A:[B,C]
#
#     B:[A,D]
#
#     C:[A,D]
#
#     D:[B,C]
#
#   Directed Graph
#
#     A:[B]
#
#     B:[C]
#
#     C:[D]
#
#     D:[A]

# %% [markdown]
# # **Travels and techniques for graph:**
#
# --> Graph supports two traversal techniques:
#
# 1. BFS(Breadth First Search)
#
# 2. DFS(Depth First Search)
#
# 1.
#  BFS:
#
# --> BFS is similar to implementation of the queue
#
#  DFS:
#
# --> It is similar to implementation of stack
#
# 2.
#
# Queue work under the principle of FIrst In First Out
#
# Stack work under the principle of Last In First Out
