# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamMahajan880/Imapct-Training-DSA-Notes/blob/main/01_SingleLinked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** Data Structure**
#
# - Performing maiplulation on the data is called data structure.
# - different manipulation are:
#     1. Storing the data
#     2. Updating the data
#     3. Retriving the data
#     4. deleting the data
# - Various data structure concept are :
#     1. Stack
#     2. Queue
#     3. Searching and shorting Techniques
#     4. linked list
#     5. Trees
#     6. Graphs
#
# ## Linked List:
# - Linked list is a collection of nodes and every node is![1.jpg](data:image/jpeg;base64,...) connected to
# - Linked list is classified into 3 types:
#     1. Single linked list
#     2. Double linked list
#     3. Circular linked list
#
# ### Single Linked List:
#    - Single Linked list is a collection of nodes and every node will contain two fields:
#    1. Data
#    2. Address
#    - The Various operation we going to perform:
#    1. Creating the node
#    2. inserting the data in the node
#    3. Displaying the data present in the node
#    4. Adding the node
#    5. deleting the node
#    6. Displaying the data in the reverse order![1.jpg](data:image/jpeg;base64,...)

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

class slist:
  def __init__(self):
    self.head=None
  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="-->")
        temp=temp.next

n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.display()
# Out:
# 10-->20-->30-->40-->

# %% [markdown]
# **Qun :- WAP to Reverse the linked list**

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def _init_(self):
        self.head=None
    def display(self):
        l=[]
        temp=self.head
        if(self.head is None):
            print("empty")
        else:
            while(temp):
                d=temp.data
                l.append(d)
                temp=temp.next
        for i in range(len(l)-1,-1,-1):
            print(l[i],end="-->")

n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.display()

# For Reversing a List
# l=[1,2,3,4,5]
# print(l)
# for i in range(len(l)-1,-1,-1):
#   print(l[i],end="---->")
# Out:
# 40-->30-->20-->10-->

# %%
# For Reverse of List, i am using another logic :-
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def _init_(self):
        self.head=None
    def display(self):
        l=[]
        temp=self.head
        if(self.head is None):
            print("empty")
        else:
            while(temp):
                d=temp.data
                l.append(d)
                temp=temp.next
        print(l[::-1])

n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.display()


# or by using reverse directly


# class Node:
#     def __init__(self,data):
#         self.data=data
#         self.next=None

# class slist:
#     def _init_(self):
#         self.head=None
#     def display(self):
#         l=[]
#         temp=self.head
#         if(self.head is None):
#             print("empty")
#         else:
#             while(temp):
#                 d=temp.data
#                 l.append(d)
#                 temp=temp.next
#         l.reverse()
#         print(l)



# n1=Node(10)
# s1=slist()
# s1.head=n1
# n2=Node(20)
# n1.next=n2
# n3=Node(30)
# n2.next=n3
# n4=Node(40)
# n3.next=n4
# s1.display()
# Out:
# [40, 30, 20, 10]

# %% [markdown]
# **Quin :- WAP to add the node in the beginning**

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

class slist: #slist - starting of list
  def __init__(self):
    self.head=None # In starting of list Head is Null

  def node_beg(self,data):
    nb=Node(data)
    temp=self.head
    self.head=nb
    nb.next=temp

  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="-->")
        temp=temp.next





n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.node_beg(5)
s1.display()
# Out:
# 5-->10-->20-->30-->40-->

# %% [markdown]
# **Qun ;- WAP to add the node at end possition**

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def __init__(self):
        self.head=None
    def display(self):
        temp=self.head
        if(self.head is None):
            print("empty")
        else:
            while(temp):
                print(temp.data,end="-->")
                temp=temp.next
    def new_node(self,data):
        ne=Node(data)
        temp=self.head
        while(temp.next):
            temp=temp.next
        temp.next=ne
        ne.next=None
n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.new_node(500)
s1.display()
# Out:
# 10-->20-->30-->40-->500-->

# %% [markdown]
# **Qun :- WAP to add a node at Specific possition**

# %% [markdown]
# ![10.jpg](data:image/jpeg;base64,...![11.jpg](data:image/jpeg;base64,...))

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def __init__(self):
        self.head=None

    def Add_p(self,p,data):
        temp=self.head
        np=Node(data)
        for i in range(1,p-1):
            temp=temp.next
            np.next=temp.next
            temp.next=np
    def display(self):
        temp=self.head
        if(self.head is None):
            print("empty")
        else:
            while(temp):
                print(temp.data,end="-->")
                temp=temp.next



n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.Add_p(3,50)
s1.display()
# Out:
# 10-->20-->50-->30-->40-->

# %% [markdown]
# **Qun :- WAP to delete first node**

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def _init_(self):
        self.head=None
    def Del_F_ele(self):
        temp=self.head
        self.head=temp.next
        temp.next=None
    def display(self):
        temp=self.head
        if(self.head is None):
            print("empty")
        else:
            while(temp):
                print(temp.data,end="-->")
                temp=temp.next
n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.Del_F_ele()
s1.display()
# Out:
# 20-->30-->40-->

# %% [markdown]
# **Qun :- WAP to delete last node**

# %% [markdown]
# ![11.jpg](data:image/jpeg;base64,...)

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def __init__(self):
        self.head=None
    def Del_ls_ele(self):
        prev=self.head
        temp=self.head.next
        while(temp.next):
            temp=temp.next
            prev=prev.next
        prev.next=None
    def display(self):
        temp=self.head
        if(self.head is None):
            print("empty")
        else:
            while(temp):
                print(temp.data,end="-->")
                temp=temp.next
n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.Del_ls_ele()
s1.display()
# Out:
# 10-->20-->30-->

# %% [markdown]
# Qun :- Delete the specific Node

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class slist:
    def _init_(self):
        self.head=None
    def Del_po_ele(self,d):
        prev=self.head
        temp=self.head.next
        #for i in range(1,p-1):          // For perticular position to remove
        #    temp=temp.next
        #    prev=prev.next
        #prev.next=temp.next

        while(temp.next):
            if(temp.data==d):
                prev.next=temp.next
            temp=temp.next
            prev=prev.next

    def display(self):
        temp=self.head
        if(self.head is None):
            print("empty")
        else:
            while(temp):
                print(temp.data,end="-->")
                temp=temp.next
n1=Node(10)
s1=slist()
s1.head=n1
n2=Node(20)
n1.next=n2
n3=Node(30)
n2.next=n3
n4=Node(40)
n3.next=n4
s1.Del_po_ele(30)
s1.display()
# Out:
# 10-->20-->40-->
