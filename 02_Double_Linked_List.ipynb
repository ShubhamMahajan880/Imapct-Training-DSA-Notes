# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamMahajan880/Imapct-Training-DSA-Notes/blob/main/02_Double_Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Double Linked List**
#
# Double Linked List is also collection of nodes.
#
#
# * and every node will be connected with the next node.
#
# * In Double Linked List every niode will contain 3 fields :-
#
# 1 - Previous(prev preveous node address)
#
# 2 - data()
#
# 3 - next()
#
# * For the first node there is no any previous node therefor its null
#
#
# * For the last node next field address will be null
#
# * the basic operations we can perform on the Double Linked List are 🇱
#
# i - Creating the Nodes
#
# ii - Inserting the data into the nodes
#
# iii- Display the data present in the node
#
# iv - Reversing the data present in the node thorugh the tail
#
# v - adding the nodes
#
# vi - Deleting the nodes ![5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![6.jpg](data:image/jpeg;base64,...)

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None

class dlist:
  def __init__(self):
    self.head=None
    self.tail=None
  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next

n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
d1.display()
# Out:
# 10--->20--->30--->40--->

# %% [markdown]
# **Qun :- WAP to reverse the linked list elements.**

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None

class dlist:
  def __init__(self):
    self.head=None
    self.tail=None
  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next

  def rdisplay(self):
    temp=self.tail
    if(self.tail is None):
      print("Empty")
    else :
      while(temp):
        print(temp.data,end="--->")
        temp=temp.prev



n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
d1.tail=n4
#d1.display()
d1.rdisplay()
# Out:
# 40--->30--->20--->10--->

# %% [markdown]
# **Qun :-** WAP to Add the Node at beginning **

# %% [markdown]
# ![7.jpg](data:image/jpeg;base64,...)

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None

class dlist:
  def __init__(self):
    self.head=None
    self.tail=None

  def node_beg(self,data):
    temp=self.head
    nb=Node(data)
    self.head=nb
    nb.next=temp
    temp.prev=nb

  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next

  def rdisplay(self):
    temp=self.tail
    if(self.tail is None):
      print("Empty")
    else :
      while(temp):
        print(temp.data,end="--->")
        temp=temp.prev



n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
d1.tail=n4
d1.node_beg(5)
d1.display()
#d1.rdisplay()
# Out:
# 5--->10--->20--->30--->40--->

# %% [markdown]
# **Qun :- Add the Node at the End **

# %% [markdown]
# ![8.jpg](data:image/jpeg;base64,...)

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None

class dlist:
  def __init__(self):
    self.head=None
    self.tail=None

  def node_end(self,data):
    temp=self.tail
    ne=Node(data)
    self.tail=ne
    ne.prev=temp
    temp.next=ne

  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next

  def rdisplay(self):
    temp=self.tail
    if(self.tail is None):
      print("Empty")
    else :
      while(temp):
        print(temp.data,end="--->")
        temp=temp.prev



n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
d1.tail=n4
d1.node_end(5)
d1.display()
#d1.rdisplay()
# Out:
# 10--->20--->30--->40--->5--->

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None

class dlist:
  def __init__(self):
    self.head=None
    self.tail=None

  def node_end(self,data):
    ne=Node(data)
    temp=self.tail
    while(temp.next):
      temp=temp.next
    temp.next=ne
    ne.prev=temp

  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next

  def rdisplay(self):
    temp=self.tail
    if(self.tail is None):
      print("Empty")
    else :
      while(temp):
        print(temp.data,end="--->")
        temp=temp.prev



n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
d1.tail=n4
d1.node_end(5)
d1.display()
#d1.rdisplay()
# Out:
# 10--->20--->30--->40--->5--->

# %% [markdown]
# **Qun :- WAP for insert Node at Specific Possition**

# %% [markdown]
# ![9.jpg](data:image/jpeg;base64,...)

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None
class dlist:
  def _init_(self):
    self.head=None
    self.tail=None

  # def node_beg(self,data):
  #   temp=self.head
  #   nb=Node(data)
  #   self.head=nb
  #   nb.next=temp
  #   temp.prev=nb

  def node_pos(self,pos,data):
    if(pos==1):
      self.node_beg()
    else:
      np=Node(data)
      temp=self.head
      for p in range (1,pos-1):
        temp=temp.next
      np.prev = temp
      np.next = temp.next
      temp.next=np
      np.next.prev=np


  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next

n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
d1.node_pos(3,25)
d1.display()
# Out:
# 10--->20--->25--->30--->40--->

# %% [markdown]
# **Qun :- WAp for Delete Head Node **

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None
class dlist:
  def _init_(self):
    self.head=None
    self.tail=None


  def del_first(self):
    temp=self.head
    self.head=temp.next
    temp.next=None


  def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next

n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
#d1.node_pos(3,25)
d1.del_first()
d1.display()
# Out:
# 20--->30--->40--->

# %% [markdown]
# **Qun :- WAp to reverse the linked list elements without using the list**

# %% [markdown]
# ![12.jpg](data:image/jpeg;base64,...)

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None

class dlist:
  def _init_(self):
    self.head=None
    self.tail=None

class dlist:
  def __init__(self):
    self.head=None
    self.tail=None

def reverse(self):
  prev=None
  current=self.head
  while(current is not None):
    next=current.next
    current.next=prev
    prev=current
    current=next
  prev=self.head

def display(self):
    temp=self.head
    if(self.head is None):
      print("Empty")
    else:
      while(temp):
        print(temp.data,end="--->")
        temp=temp.next


n1=Node(10)
d1=dlist()
d1.head=n1
n2=Node(20)
n1.next=n2
n2.prev=n1
n3=Node(30)
n2.next=n3
n3.prev=n2
n4=Node(40)
n3.next=n4
n4.prev=n3
d1=reverse(15)
d1.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f5739bf7ad59> in <cell line: 44>()
#      42 n3.next=n4
#      43 n4.prev=n3
# ---> 44 d1=reverse(15)
#      45 d1.display()
#      46
#
# <ipython-input-5-f5739bf7ad59> in reverse(self)
#      12 def reverse(self):
#      13   prev=None
# ---> 14   current=self.head
#      15   while(current is not None):
#      16     next=current.next
#
# AttributeError: 'int' object has no attribute 'head'
